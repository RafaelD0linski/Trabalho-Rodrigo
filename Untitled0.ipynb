# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelD0linski/-landing-page-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Célula 2
# !pip install numpy pandas scikit-learn matplotlib

# %%
# Célula 3
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt

print("Bibliotecas importadas com sucesso!")
# Out:
# Bibliotecas importadas com sucesso!

# %%
# Célula 4 - Carregar dataset
iris = load_iris()
X = iris.data
y = iris.target

print("Shape dos dados:", X.shape)
print("Classes:", iris.target_names)
print("\nPrimeiras linhas do dataset:")
pd.DataFrame(X, columns=iris.feature_names).head()
# Out:
# Shape dos dados: (150, 4)
# Classes: ['setosa' 'versicolor' 'virginica']
#
# Primeiras linhas do dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# # Célula 5 - Dividir em treino e teste
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# print("Tamanho treino:", X_train.shape)
# print("Tamanho teste:", X_test.shape)

# %% [markdown]
# # Célula 6 - Padronizar os dados (importante para SVM)
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
#
# print("Dados normalizados!")

# %% [markdown]
# # Célula 7 - Treinar o modelo SVM
# svm = SVC(kernel='rbf', C=1.0, random_state=42)
# svm.fit(X_train_scaled, y_train)
#
# print("Modelo SVM treinado com sucesso!")

# %% [markdown]
# # Célula 8 - Avaliar o modelo
# y_pred = svm.predict(X_test_scaled)
#
# print("Acurácia:", accuracy_score(y_test, y_pred))
# print("\nMatriz de confusão:\n", confusion_matrix(y_test, y_pred))
# print("\nRelatório de classificação:\n", classification_report(y_test, y_pred))

# %% [markdown]
# # Célula 9 - Comparar diferentes kernels
# kernels = ['linear', 'poly', 'rbf', 'sigmoid']
# scores = []
#
# for kernel in kernels:
#     svm = SVC(kernel=kernel, random_state=42)
#     svm.fit(X_train_scaled, y_train)
#     scores.append(svm.score(X_test_scaled, y_test))
#
# plt.figure(figsize=(8,4))
# plt.bar(kernels, scores, color=['blue', 'green', 'red', 'orange'])
# plt.title("Acurácia por tipo de Kernel")
# plt.xlabel("Kernel")
# plt.ylabel("Acurácia")
# plt.ylim([0.8, 1.0])
# plt.grid(True, axis='y')
# plt.show()
